# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, confusion_matrix
)

# --- KONFIGURASI PATH MODEL DAN HISTORY ---
model_paths = {}

for i in range(1, 10):  # Dari Exp-1 hingga Exp-8
    key = f"P{i}"
    model_file = f"model/trainTest{i}_model.h5"
    history_file = f"history/trainTest{i}_history.json"
    model_paths[key] = (model_file, history_file)


train_df = pd.read_csv("dataset/train_data.csv")
val_df = pd.read_csv("dataset/val_data.csv")
test_df = pd.read_csv("dataset/test_data.csv")

# --- Pisahkan fitur dan label ---
X_train = train_df.drop("DEPRESSED", axis=1).values
y_train = train_df["DEPRESSED"].values

X_val = val_df.drop("DEPRESSED", axis=1).values
y_val = val_df["DEPRESSED"].values

X_test = test_df.drop("DEPRESSED", axis=1).values
y_test = test_df["DEPRESSED"].values

# --- Scaling ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# --- Reshape untuk CNN 1D ---
X_train_scaled = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_scaled = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)
X_test_scaled = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# --- PROSES LOOP SEMUA MODEL ---
for name, (model_file, history_file) in model_paths.items():
    print(f"\n📦 Evaluating model: {name}")

    # Load model dan history
    model = load_model(model_file)
    with open(history_file, "r") as f:
        history = json.load(f)

    # Prediksi
    y_pred_prob = model.predict(X_test_scaled)
    y_pred = (y_pred_prob > 0.5).astype("int32")

    # --- Hitung Metrics ---
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print(f"Accuracy: {acc:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f} | F1 Score: {f1:.4f}")

    # --- Plot Akurasi dan Loss ---
    plt.figure(figsize=(12, 6))
    plt.suptitle(f'Model: {name}', fontsize=16)

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

    # --- Confusion Matrix (Heatmap) ---
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['No Depression', 'Depression'],
                yticklabels=['No Depression', 'Depression'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - {name}')
    plt.tight_layout()
    plt.show()

    # --- Classification Report ---
    print(f"\n📊 Classification Report - {name}")
    print(classification_report(y_test, y_pred, digits=4))

    print(f"Accuracy: {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall: {rec:.4f}")
    print(f"F1 Score: {f1:.4f}")
# Out:
# 📦 Evaluating model: P1
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Accuracy: 0.8852 | Precision: 0.9143 | Recall: 0.8889 | F1 Score: 0.9014
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📊 Classification Report - P1
#               precision    recall  f1-score   support
#
#            0     0.8462    0.8800    0.8627        25
#            1     0.9143    0.8889    0.9014        36
#
#     accuracy                         0.8852        61
#    macro avg     0.8802    0.8844    0.8821        61
# weighted avg     0.8864    0.8852    0.8856        61
#
# Accuracy: 0.8852
# Precision: 0.9143
# Recall: 0.8889
# F1 Score: 0.9014
#
# 📦 Evaluating model: P2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Accuracy: 0.8525 | Precision: 0.8857 | Recall: 0.8611 | F1 Score: 0.8732
# 📊 Classification Report - P2
#               precision    recall  f1-score   support
#
#            0     0.8077    0.8400    0.8235        25
#            1     0.8857    0.8611    0.8732        36
#
#     accuracy                         0.8525        61
#    macro avg     0.8467    0.8506    0.8484        61
# weighted avg     0.8537    0.8525    0.8529        61
#
# Accuracy: 0.8525
# Precision: 0.8857
# Recall: 0.8611
# F1 Score: 0.8732
#
# 📦 Evaluating model: P3
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Accuracy: 0.8852 | Precision: 0.9394 | Recall: 0.8611 | F1 Score: 0.8986
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📊 Classification Report - P3
#               precision    recall  f1-score   support
#
#            0     0.8214    0.9200    0.8679        25
#            1     0.9394    0.8611    0.8986        36
#
#     accuracy                         0.8852        61
#    macro avg     0.8804    0.8906    0.8832        61
# weighted avg     0.8910    0.8852    0.8860        61
#
# Accuracy: 0.8852
# Precision: 0.9394
# Recall: 0.8611
# F1 Score: 0.8986
#
# 📦 Evaluating model: P4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Accuracy: 0.8852 | Precision: 0.9143 | Recall: 0.8889 | F1 Score: 0.9014
# 📊 Classification Report - P4
#               precision    recall  f1-score   support
#
#            0     0.8462    0.8800    0.8627        25
#            1     0.9143    0.8889    0.9014        36
#
#     accuracy                         0.8852        61
#    macro avg     0.8802    0.8844    0.8821        61
# weighted avg     0.8864    0.8852    0.8856        61
#
# Accuracy: 0.8852
# Precision: 0.9143
# Recall: 0.8889
# F1 Score: 0.9014
#
# 📦 Evaluating model: P5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Accuracy: 0.8197 | Precision: 0.9032 | Recall: 0.7778 | F1 Score: 0.8358
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📊 Classification Report - P5
#               precision    recall  f1-score   support
#
#            0     0.7333    0.8800    0.8000        25
#            1     0.9032    0.7778    0.8358        36
#
#     accuracy                         0.8197        61
#    macro avg     0.8183    0.8289    0.8179        61
# weighted avg     0.8336    0.8197    0.8211        61
#
# Accuracy: 0.8197
# Precision: 0.9032
# Recall: 0.7778
# F1 Score: 0.8358
#
# 📦 Evaluating model: P6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Accuracy: 0.8525 | Precision: 0.9091 | Recall: 0.8333 | F1 Score: 0.8696
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📊 Classification Report - P6
#               precision    recall  f1-score   support
#
#            0     0.7857    0.8800    0.8302        25
#            1     0.9091    0.8333    0.8696        36
#
#     accuracy                         0.8525        61
#    macro avg     0.8474    0.8567    0.8499        61
# weighted avg     0.8585    0.8525    0.8534        61
#
# Accuracy: 0.8525
# Precision: 0.9091
# Recall: 0.8333
# F1 Score: 0.8696
#
# 📦 Evaluating model: P7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Accuracy: 0.8197 | Precision: 0.9032 | Recall: 0.7778 | F1 Score: 0.8358
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📊 Classification Report - P7
#               precision    recall  f1-score   support
#
#            0     0.7333    0.8800    0.8000        25
#            1     0.9032    0.7778    0.8358        36
#
#     accuracy                         0.8197        61
#    macro avg     0.8183    0.8289    0.8179        61
# weighted avg     0.8336    0.8197    0.8211        61
#
# Accuracy: 0.8197
# Precision: 0.9032
# Recall: 0.7778
# F1 Score: 0.8358
#
# 📦 Evaluating model: P8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Accuracy: 0.8197 | Precision: 0.9032 | Recall: 0.7778 | F1 Score: 0.8358
# 📊 Classification Report - P8
#               precision    recall  f1-score   support
#
#            0     0.7333    0.8800    0.8000        25
#            1     0.9032    0.7778    0.8358        36
#
#     accuracy                         0.8197        61
#    macro avg     0.8183    0.8289    0.8179        61
# weighted avg     0.8336    0.8197    0.8211        61
#
# Accuracy: 0.8197
# Precision: 0.9032
# Recall: 0.7778
# F1 Score: 0.8358
#
# 📦 Evaluating model: P9
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 54
#      51 print(f"\n📦 Evaluating model: {name}")
#      53 # Load model dan history
# ---> 54 model = load_model(model_file)
#      55 with open(history_file, "r") as f:
#      56     history = json.load(f)
#
# File c:\Users\bania\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File c:\Users\bania\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File c:\Users\bania\AppData\Local\Programs\Python\Python312\Lib\site-packages\h5py\_hl\files.py:564, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     555     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     556                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     557                      alignment_threshold=alignment_threshold,
#     558                      alignment_interval=alignment_interval,
#     559                      meta_block_size=meta_block_size,
#     560                      **kwds)
#     561     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     562                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                      fs_page_size=fs_page_size)
# --> 564     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     566 if isinstance(libver, tuple):
#     567     self._libver = libver
#
# File c:\Users\bania\AppData\Local\Programs\Python\Python312\Lib\site-packages\h5py\_hl\files.py:238, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236     if swmr and swmr_support:
#     237         flags |= h5f.ACC_SWMR_READ
# --> 238     fid = h5f.open(name, flags, fapl=fapl)
#     239 elif mode == 'r+':
#     240     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'model/trainTest9_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
